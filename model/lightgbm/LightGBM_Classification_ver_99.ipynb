# %% [markdown]
# # LightGBM을 사용한 ML(폐업률 평균값 기준으로 이진분류)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, average_precision_score, confusion_matrix,
    precision_recall_curve
)
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
import lightgbm as lgb

# %%
# 데이터 로드
df = pd.read_csv('../../eda/data/merged_data.csv')

# %%
df.head()
# Out:
#    기준_년분기_코드 자치구_코드_명 서비스_업종_코드_명   점포_수  유사_업종_점포_수  개업_률  개업_점포_수  폐업_률  \
# 0      20191      강남구         PC방  122.0       132.0   9.8     13.0   6.8
# 1      20191      강남구          가구  435.0       436.0   2.8     12.0   0.7
# 2      20191      강남구          가방  279.0       280.0   4.3     12.0   3.6
# 3      20191      강남구        가전제품  163.0       163.0   1.8      3.0   1.2
# 4      20191      강남구      가전제품수리   92.0        92.0   3.3      3.0   1.1
#
#    폐업_점포_수  프랜차이즈_점포_수  ...  남성연령대_30_직장_인구_수  남성연령대_40_직장_인구_수  \
# 0      9.0        10.0  ...          178522.0          164466.0
# 1      3.0         1.0  ...          178522.0          164466.0
# 2     10.0         1.0  ...          178522.0          164466.0
# 3      2.0         0.0  ...          178522.0          164466.0
# 4      1.0         0.0  ...          178522.0          164466.0
#
#    남성연령대_50_직장_인구_수  남성연령대_60_이상_직장_인구_수  여성연령대_10_직장_인구_수  여성연령대_20_직장_인구_수  \
# 0          100728.0              44021.0            1679.0           99408.0
# 1          100728.0              44021.0            1679.0           99408.0
# 2          100728.0              44021.0            1679.0           99408.0
# 3          100728.0              44021.0            1679.0           99408.0
# 4          100728.0              44021.0            1679.0           99408.0
#
#    여성연령대_30_직장_인구_수  여성연령대_40_직장_인구_수  여성연령대_50_직장_인구_수  여성연령대_60_이상_직장_인구_수
# 0          108205.0           74466.0           54523.0              22838.0
# 1          108205.0           74466.0           54523.0              22838.0
# 2          108205.0           74466.0           54523.0              22838.0
# 3          108205.0           74466.0           54523.0              22838.0
# 4          108205.0           74466.0           54523.0              22838.0
#
# [5 rows x 137 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39975 entries, 0 to 39974
# Columns: 137 entries, 기준_년분기_코드 to 여성연령대_60_이상_직장_인구_수
# dtypes: float64(132), int64(2), object(3)
# memory usage: 41.8+ MB

# %%
df.describe()
# Out:
#           기준_년분기_코드          점포_수    유사_업종_점포_수          개업_률       개업_점포_수  \
# count  39975.000000  39975.000000  39975.000000  39975.000000  39975.000000
# mean   20220.096635    320.453959    353.995822      2.971897     11.176735
# std       18.764856    624.817403    648.030094      2.385172     21.887316
# min    20191.000000      3.000000      3.000000      0.000000      0.000000
# 25%    20203.000000     94.000000    105.000000      1.300000      2.000000
# 50%    20221.000000    161.000000    188.000000      2.600000      5.000000
# 75%    20234.000000    313.000000    357.000000      4.200000     12.000000
# max    20252.000000  17827.000000  17845.000000     43.600000    773.000000
#
#                폐업_률       폐업_점포_수    프랜차이즈_점포_수      당월_매출_금액      당월_매출_건수  \
# count  39975.000000  39975.000000  39975.000000  3.997500e+04  3.997500e+04
# mean       2.589829      9.794196     33.541864  1.553588e+10  5.749521e+05
# std        2.001541     19.292389     71.256850  4.679056e+10  1.482439e+06
# min        0.000000      0.000000      0.000000  7.135000e+03  2.000000e+00
# 25%        1.200000      2.000000      0.000000  1.197476e+09  1.463000e+04
# 50%        2.300000      4.000000      4.000000  4.114511e+09  7.159500e+04
# 75%        3.600000     10.000000     27.000000  1.251953e+10  3.641125e+05
# max       33.300000    554.000000    688.000000  1.399137e+12  2.716973e+07
#
#        ...  남성연령대_30_직장_인구_수  남성연령대_40_직장_인구_수  남성연령대_50_직장_인구_수  \
# count  ...      39975.000000      39975.000000      39975.000000
# mean   ...      27142.451857      26395.847330      19736.054484
# std    ...      39941.977062      36960.317249      24219.922727
# min    ...       1169.000000       1978.000000       2704.000000
# 25%    ...       5590.000000       5799.000000       5397.000000
# 50%    ...       9123.000000      10094.000000      10122.000000
# 75%    ...      24849.000000      24451.000000      18373.000000
# max    ...     204697.000000     188865.000000     116356.000000
#
#        남성연령대_60_이상_직장_인구_수  여성연령대_10_직장_인구_수  여성연령대_20_직장_인구_수  \
# count         39975.000000      39975.000000      39975.000000
# mean           9543.760350        223.790644      15057.239225
# std            9600.950081        399.065330      22371.870231
# min            2245.000000          0.000000        635.000000
# 25%            3928.000000          0.000000       3138.000000
# 50%            5924.000000         39.000000       5068.000000
# 75%           10207.000000        209.000000      21296.000000
# max           51339.000000       1679.000000     114671.000000
#
#        여성연령대_30_직장_인구_수  여성연령대_40_직장_인구_수  여성연령대_50_직장_인구_수  \
# count      39975.000000      39975.000000      39975.000000
# mean       17365.139937      13473.701138      10014.440951
# std        24534.250632      16564.421275      11715.352615
# min         1180.000000       1674.000000       1663.000000
# 25%         3795.000000       4042.000000       3856.000000
# 50%         6673.000000       6807.000000       5695.000000
# 75%        21114.000000      14062.000000       8866.000000
# max       124729.000000      86333.000000      63848.000000
#
#        여성연령대_60_이상_직장_인구_수
# count         39975.000000
# mean           4391.736785
# std            4832.596737
# min             257.000000
# 25%            1695.000000
# 50%            2678.000000
# 75%            4775.000000
# max           26816.000000
#
# [8 rows x 134 columns]

# %%
# =========================================================
# LightGBM + SMOTE + Stratified K-Fold(5) + GridSearchCV
# Split: train 0.7 / val 0.1 / test 0.2 (all stratified)
# 평가: ACC/PREC/RECALL/F1/ROC-AUC/PR-AUC (VAL에서 F1 기준 임계값 -> TEST 적용)
# =========================================================

RANDOM_STATE = 42

# --- 타깃 생성: 상위 25% → 1 ---
assert '폐업_률' in df.columns, "'폐업_률' 컬럼이 필요합니다."
df = df.dropna(subset=['폐업_률']).copy()

cut_75 = df['폐업_률'].quantile(0.75)   # 75% 분위수
df['폐업률_등급'] = (df['폐업_률'] > cut_75).astype(int)

print(f"임계값(75% 분위수) = {cut_75:.4f}")
print("라벨 분포:", df['폐업률_등급'].value_counts().to_dict())

# 불필요 컬럼 제거
drop_cols = ['폐업_점포_수', '폐업_영업_개월_평균', '서울시_폐업_영업_개월_평균', '기준_년분기_코드']
df = df.drop(columns=[c for c in drop_cols if c in df.columns], errors='ignore')
# Out:
# 임계값(75% 분위수) = 3.6000
# 라벨 분포: {0: 30153, 1: 9822}

# %%
# ---------- 1) 특징/타깃 분리 ----------
target = '폐업률_등급'
X = df.drop(columns=['폐업_률', target], errors='ignore')
y = df[target].astype(int)

# %%
# ---------- 2) 열 타입에 따라 전처리 파이프라인 구성 ----------
cat_cols = [c for c in X.columns if X[c].dtype.name in ['object', 'category']]
num_cols = [c for c in X.columns if c not in cat_cols]

# 범주형: OrdinalEncoder(unknown=-1), 수치형: 그대로
preprocess = ColumnTransformer(
    transformers=[
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), cat_cols),
        ('num', 'passthrough', num_cols)
    ],
    remainder='drop'
)

# %%
# ---------- 3) 데이터 분할: train 0.7 / val 0.1 / test 0.2 ----------
# 1) 먼저 test 0.2 분리
X_trval, X_test, y_trval, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=RANDOM_STATE
)
# 2) 남은 0.8 중에서 train 0.7 & val 0.1 비율로 분리 (→ 0.8 * 0.125 = 0.1)
X_train, X_val, y_train, y_val = train_test_split(
    X_trval, y_trval,
    test_size=0.125,  # 0.8 * 0.125 = 0.1
    stratify=y_trval, random_state=RANDOM_STATE
)

print("분포 확인:",
      "\n  Train:", y_train.value_counts().to_dict(),
      "\n  Val  :", y_val.value_counts().to_dict(),
      "\n  Test :", y_test.value_counts().to_dict()
)
# Out:
# 분포 확인:
#   Train: {0: 21106, 1: 6876}
#   Val  : {0: 3016, 1: 982}
#   Test : {0: 6031, 1: 1964}

# %%
# ---------- 4) 파이프라인: Preprocess -> SMOTE -> LGBM ----------
# SMOTE는 파이프라인 내부에 있어 "훈련 폴드"에서만 적용됩니다.
pipeline = Pipeline(steps=[
    ('prep', preprocess),
    ('smote', SMOTE(random_state=RANDOM_STATE)),
    ('clf', lgb.LGBMClassifier(
        objective='binary',
        random_state=RANDOM_STATE,
        n_jobs=-1
    ))
])

# %%
# === (교체) 5) Stratified K-Fold(5) + Optuna (n_trials=50) ===
# 전처리: from imblearn.pipeline import Pipeline 로 구성된 pipeline이어야 합니다.
import optuna
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.base import clone
import numpy as np

# ── 안정성 가드 ─────────────────────────────────────────────────────────
# 필수 객체가 존재하는지 확인
for name in ["pipeline", "X_train", "y_train", "X_val", "y_val", "RANDOM_STATE"]:
    assert name in globals(), f"{name} 이(가) 정의되어 있어야 합니다."

# pipeline 구성 점검
assert hasattr(pipeline, "named_steps"), "pipeline은 imblearn.pipeline.Pipeline 이어야 합니다."
assert "prep" in pipeline.named_steps, "pipeline.named_steps에 'prep' 스텝이 필요합니다."
assert "clf" in pipeline.named_steps, "pipeline.named_steps에 'clf' 스텝이 필요합니다."

# Stratified K-Fold(5)
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

# ── Optuna 목적함수: PR-AUC(average_precision) 최대화 ────────────────
def objective(trial):
    params = {
        "clf__n_estimators":    trial.suggest_int(   "clf__n_estimators", 800, 5000),
        "clf__learning_rate":   trial.suggest_float( "clf__learning_rate", 0.01, 0.1, log=True),
        "clf__num_leaves":      trial.suggest_int(   "clf__num_leaves", 31, 255),
        "clf__max_depth":       trial.suggest_int(   "clf__max_depth", -1, 12),
        "clf__min_child_samples": trial.suggest_int( "clf__min_child_samples", 20, 200),
        "clf__subsample":       trial.suggest_float( "clf__subsample", 0.6, 1.0),
        "clf__subsample_freq":  trial.suggest_int(   "clf__subsample_freq", 0, 1),
        "clf__colsample_bytree":trial.suggest_float( "clf__colsample_bytree", 0.6, 1.0),
        "clf__reg_lambda":      trial.suggest_float( "clf__reg_lambda", 0.0, 2.0),
        "clf__reg_alpha":       trial.suggest_float( "clf__reg_alpha", 0.0, 1.0),
        "clf__max_bin":         trial.suggest_int(   "clf__max_bin", 255, 511),
    }

    # 파이프라인( prep → SMOTE → LGBM )에 파라미터 주입
    pipe = pipeline.set_params(**params)

    # 교차검증으로 평균 PR-AUC 계산
    scores = cross_val_score(
        pipe, X_train, y_train,
        scoring="average_precision",
        cv=cv,
        n_jobs=-1
    )
    return float(np.mean(scores))

# ── Optuna 최적화 실행 (n_trials=50) ────────────────────────────────
sampler = optuna.samplers.TPESampler(seed=RANDOM_STATE)
study = optuna.create_study(direction="maximize", sampler=sampler)
study.optimize(objective, n_trials=50)

print("\n=== Optuna 결과 ===")
print("Best score (CV-PR-AUC):", round(study.best_value, 4))
print("Best params:", study.best_params)

# ── 최적 파이프라인 생성 ────────────────────────────────────────────
best_pipe = pipeline.set_params(**study.best_params)

# ── 전처리기 선-fit 후, VAL 미리 변환 (NotFittedError 예방) ─────────────
prep = clone(best_pipe.named_steps["prep"]).fit(X_train, y_train)
X_val_t = prep.transform(X_val)

# ── 조기 종료용 리핏: 트리 수 크게 설정 후 VAL로 early_stopping ───────
best_pipe.set_params(clf__n_estimators=5000)

best_pipe.fit(
    X_train, y_train,
    # eval_set은 파이프라인을 거치지 않고 최종 모델로 직접 전달됨 → 전처리된 X_val_t 사용
    clf__eval_set=[(X_val_t, y_val)],
    clf__eval_metric='auc',
    clf__callbacks=[lgb.early_stopping(stopping_rounds=200, verbose=False)]
)

best_clf = best_pipe.named_steps["clf"]
print("best_iteration_ (with early stopping on VAL):", getattr(best_clf, "best_iteration_", None))

from imblearn.pipeline import Pipeline as ImbPipeline
assert isinstance(pipeline, ImbPipeline), "pipeline은 imblearn.pipeline.Pipeline 여야 합니다."
y_train = y_train.astype(int); y_val = y_val.astype(int)  # LGBM 이진 라벨 안전 캐스팅
# Out:
# [I 2025-10-14 01:39:44,905] A new study created in memory with name: no-name-ae888aa5-ad34-4209-a0cc-f637be8020b8
# [I 2025-10-14 01:41:10,186] Trial 0 finished with value: 0.6311779677297049 and parameters: {'clf__n_estimators': 2373, 'clf__learning_rate': 0.08927180304353628, 'clf__num_leaves': 195, 'clf__max_depth': 7, 'clf__min_child_samples': 48, 'clf__subsample': 0.662397808134481, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9464704583099741, 'clf__reg_lambda': 1.2022300234864176, 'clf__reg_alpha': 0.7080725777960455, 'clf__max_bin': 260}. Best is trial 0 with value: 0.6311779677297049.
# [I 2025-10-14 01:41:36,475] Trial 1 finished with value: 0.6055930906225429 and parameters: {'clf__n_estimators': 4874, 'clf__learning_rate': 0.06798962421591129, 'clf__num_leaves': 78, 'clf__max_depth': 1, 'clf__min_child_samples': 53, 'clf__subsample': 0.7216968971838151, 'clf__subsample_freq': 1, 'clf__colsample_bytree': 0.7727780074568463, 'clf__reg_lambda': 0.5824582803960838, 'clf__reg_alpha': 0.6118528947223795, 'clf__max_bin': 290}. Best is trial 0 with value: 0.6311779677297049.
# [I 2025-10-14 01:43:03,344] Trial 2 finished with value: 0.6403483838185982 and parameters: {'clf__n_estimators': 2027, 'clf__learning_rate': 0.023246728489504348, 'clf__num_leaves': 133, 'clf__max_depth': 9, 'clf__min_child_samples': 56, 'clf__subsample': 0.8056937753654446, 'clf__subsample_freq': 1, 'clf__colsample_bytree': 0.6185801650879991, 'clf__reg_lambda': 1.2150897038028767, 'clf__reg_alpha': 0.17052412368729153, 'clf__max_bin': 271}. Best is trial 2 with value: 0.6403483838185982.
# [I 2025-10-14 01:43:43,467] Trial 3 finished with value: 0.6324479358146348 and parameters: {'clf__n_estimators': 4786, 'clf__learning_rate': 0.0923915031962725, 'clf__num_leaves': 212, 'clf__max_depth': 3, 'clf__min_child_samples': 37, 'clf__subsample': 0.8736932106048627, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.6488152939379115, 'clf__reg_lambda': 0.9903538202225404, 'clf__reg_alpha': 0.034388521115218396, 'clf__max_bin': 488}. Best is trial 2 with value: 0.6403483838185982.
# [I 2025-10-14 01:45:03,332] Trial 4 finished with value: 0.6413687620722415 and parameters: {'clf__n_estimators': 1887, 'clf__learning_rate': 0.04597505784732168, 'clf__num_leaves': 101, 'clf__max_depth': 6, 'clf__min_child_samples': 118, 'clf__subsample': 0.6739417822102108, 'clf__subsample_freq': 1, 'clf__colsample_bytree': 0.9100531293444458, 'clf__reg_lambda': 1.8789978831283782, 'clf__reg_alpha': 0.8948273504276488, 'clf__max_bin': 408}. Best is trial 4 with value: 0.6413687620722415.
# [I 2025-10-14 01:50:16,670] Trial 5 finished with value: 0.6424264092412473 and parameters: {'clf__n_estimators': 4672, 'clf__learning_rate': 0.012260057359187526, 'clf__num_leaves': 75, 'clf__max_depth': -1, 'clf__min_child_samples': 78, 'clf__subsample': 0.7554709158757928, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9314950036607718, 'clf__reg_lambda': 0.7135066533871786, 'clf__reg_alpha': 0.28093450968738076, 'clf__max_bin': 394}. Best is trial 5 with value: 0.6424264092412473.
# [I 2025-10-14 01:51:21,428] Trial 6 finished with value: 0.6405285421620873 and parameters: {'clf__n_estimators': 1392, 'clf__learning_rate': 0.0634157277549528, 'clf__num_leaves': 47, 'clf__max_depth': 12, 'clf__min_child_samples': 159, 'clf__subsample': 0.679486272613669, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9261845713819337, 'clf__reg_lambda': 1.4137146876952342, 'clf__reg_alpha': 0.7290071680409873, 'clf__max_bin': 453}. Best is trial 5 with value: 0.6424264092412473.
# [I 2025-10-14 01:52:12,445] Trial 7 finished with value: 0.656285945688146 and parameters: {'clf__n_estimators': 1111, 'clf__learning_rate': 0.02282788775990513, 'clf__num_leaves': 57, 'clf__max_depth': 11, 'clf__min_child_samples': 132, 'clf__subsample': 0.7323592099410596, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.7243929286862649, 'clf__reg_lambda': 0.6503666440534941, 'clf__reg_alpha': 0.7296061783380641, 'clf__max_bin': 418}. Best is trial 7 with value: 0.656285945688146.
# [I 2025-10-14 01:54:42,899] Trial 8 finished with value: 0.6320603824096528 and parameters: {'clf__n_estimators': 4527, 'clf__learning_rate': 0.029662989987000676, 'clf__num_leaves': 57, 'clf__max_depth': 8, 'clf__min_child_samples': 157, 'clf__subsample': 0.8245108790277985, 'clf__subsample_freq': 1, 'clf__colsample_bytree': 0.7975182385457563, 'clf__reg_lambda': 1.0454656587639881, 'clf__reg_alpha': 0.42754101835854963, 'clf__max_bin': 261}. Best is trial 7 with value: 0.656285945688146.
# [I 2025-10-14 01:54:56,471] Trial 9 finished with value: 0.6123760149195429 and parameters: {'clf__n_estimators': 1253, 'clf__learning_rate': 0.010750512925563078, 'clf__num_leaves': 174, 'clf__max_depth': 3, 'clf__min_child_samples': 112, 'clf__subsample': 0.9630265895704372, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.7641531692142519, 'clf__reg_lambda': 1.5111022770860973, 'clf__reg_alpha': 0.22879816549162246, 'clf__max_bin': 274}. Best is trial 7 with value: 0.656285945688146.
# [I 2025-10-14 01:57:04,104] Trial 10 finished with value: 0.6424606210569845 and parameters: {'clf__n_estimators': 2957, 'clf__learning_rate': 0.018784996368880296, 'clf__num_leaves': 249, 'clf__max_depth': 12, 'clf__min_child_samples': 194, 'clf__subsample': 0.6154900799844731, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.7156237038334943, 'clf__reg_lambda': 0.1161931729724841, 'clf__reg_alpha': 0.9923626654603367, 'clf__max_bin': 331}. Best is trial 7 with value: 0.656285945688146.
# [I 2025-10-14 02:00:25,720] Trial 11 finished with value: 0.6410564945357704 and parameters: {'clf__n_estimators': 3393, 'clf__learning_rate': 0.019313203137083224, 'clf__num_leaves': 236, 'clf__max_depth': 12, 'clf__min_child_samples': 193, 'clf__subsample': 0.6083293413232247, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.7019179457565944, 'clf__reg_lambda': 0.008817161194820719, 'clf__reg_alpha': 0.9570886666521083, 'clf__max_bin': 338}. Best is trial 7 with value: 0.656285945688146.
# [I 2025-10-14 02:03:22,320] Trial 12 finished with value: 0.644806483123047 and parameters: {'clf__n_estimators': 3358, 'clf__learning_rate': 0.01728642875085533, 'clf__num_leaves': 252, 'clf__max_depth': 11, 'clf__min_child_samples': 197, 'clf__subsample': 0.6049898371672249, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.694085486904971, 'clf__reg_lambda': 0.004621459424679911, 'clf__reg_alpha': 0.835980578679128, 'clf__max_bin': 333}. Best is trial 7 with value: 0.656285945688146.
# [I 2025-10-14 02:05:54,378] Trial 13 finished with value: 0.6457194065960892 and parameters: {'clf__n_estimators': 3665, 'clf__learning_rate': 0.015068734523654865, 'clf__num_leaves': 134, 'clf__max_depth': 9, 'clf__min_child_samples': 157, 'clf__subsample': 0.7421902170733858, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.8527250207789754, 'clf__reg_lambda': 0.38646706351131616, 'clf__reg_alpha': 0.799077535923226, 'clf__max_bin': 353}. Best is trial 7 with value: 0.656285945688146.
# [I 2025-10-14 02:09:03,799] Trial 14 finished with value: 0.6348455578198037 and parameters: {'clf__n_estimators': 3913, 'clf__learning_rate': 0.03401674260923995, 'clf__num_leaves': 141, 'clf__max_depth': 9, 'clf__min_child_samples': 143, 'clf__subsample': 0.7406086632532847, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.8625585250410275, 'clf__reg_lambda': 0.38575662041628317, 'clf__reg_alpha': 0.4752706940999633, 'clf__max_bin': 432}. Best is trial 7 with value: 0.656285945688146.
# [I 2025-10-14 02:09:37,744] Trial 15 finished with value: 0.6551176559356648 and parameters: {'clf__n_estimators': 837, 'clf__learning_rate': 0.014354615858231057, 'clf__num_leaves': 34, 'clf__max_depth': 10, 'clf__min_child_samples': 133, 'clf__subsample': 0.8628581217310244, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.8480595631138229, 'clf__reg_lambda': 0.42656667126224457, 'clf__reg_alpha': 0.6089582803996043, 'clf__max_bin': 365}. Best is trial 7 with value: 0.656285945688146.
# [I 2025-10-14 02:10:18,740] Trial 16 finished with value: 0.6546534581013098 and parameters: {'clf__n_estimators': 1017, 'clf__learning_rate': 0.027735259995621556, 'clf__num_leaves': 35, 'clf__max_depth': 10, 'clf__min_child_samples': 80, 'clf__subsample': 0.8930757645704469, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9860930071516778, 'clf__reg_lambda': 0.7539919415327564, 'clf__reg_alpha': 0.5332522163276114, 'clf__max_bin': 378}. Best is trial 7 with value: 0.656285945688146.
# [I 2025-10-14 02:10:43,079] Trial 17 finished with value: 0.6405511030958948 and parameters: {'clf__n_estimators': 939, 'clf__learning_rate': 0.013565078135236738, 'clf__num_leaves': 106, 'clf__max_depth': 5, 'clf__min_child_samples': 134, 'clf__subsample': 0.9860555624127962, 'clf__subsample_freq': 1, 'clf__colsample_bytree': 0.8520162870206658, 'clf__reg_lambda': 0.38939897654941713, 'clf__reg_alpha': 0.6234042977435617, 'clf__max_bin': 498}. Best is trial 7 with value: 0.656285945688146.
# [I 2025-10-14 02:12:04,853] Trial 18 finished with value: 0.641873570825693 and parameters: {'clf__n_estimators': 1671, 'clf__learning_rate': 0.040197912166182875, 'clf__num_leaves': 75, 'clf__max_depth': 10, 'clf__min_child_samples': 90, 'clf__subsample': 0.8673120510501788, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.7384476231194753, 'clf__reg_lambda': 0.8000759091158156, 'clf__reg_alpha': 0.36249389957804273, 'clf__max_bin': 456}. Best is trial 7 with value: 0.656285945688146.
# [I 2025-10-14 02:12:50,467] Trial 19 finished with value: 0.652420158654577 and parameters: {'clf__n_estimators': 2402, 'clf__learning_rate': 0.02279177000520841, 'clf__num_leaves': 34, 'clf__max_depth': 5, 'clf__min_child_samples': 97, 'clf__subsample': 0.9402468530565207, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.8348613994323515, 'clf__reg_lambda': 0.24747817882575385, 'clf__reg_alpha': 0.60305730591694, 'clf__max_bin': 369}. Best is trial 7 with value: 0.656285945688146.
# [I 2025-10-14 02:13:38,910] Trial 20 finished with value: 0.6538049612962075 and parameters: {'clf__n_estimators': 1480, 'clf__learning_rate': 0.014955522328275605, 'clf__num_leaves': 111, 'clf__max_depth': 7, 'clf__min_child_samples': 173, 'clf__subsample': 0.7764133828937824, 'clf__subsample_freq': 1, 'clf__colsample_bytree': 0.6532201048537976, 'clf__reg_lambda': 0.5439330310684534, 'clf__reg_alpha': 0.723767709613575, 'clf__max_bin': 310}. Best is trial 7 with value: 0.656285945688146.
# [I 2025-10-14 02:14:09,715] Trial 21 finished with value: 0.6558923663922255 and parameters: {'clf__n_estimators': 818, 'clf__learning_rate': 0.026970625509938548, 'clf__num_leaves': 31, 'clf__max_depth': 10, 'clf__min_child_samples': 131, 'clf__subsample': 0.9071390154223987, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9871013003751492, 'clf__reg_lambda': 0.7888995284779332, 'clf__reg_alpha': 0.5535216723892747, 'clf__max_bin': 412}. Best is trial 7 with value: 0.656285945688146.
# [I 2025-10-14 02:14:54,541] Trial 22 finished with value: 0.656884902977991 and parameters: {'clf__n_estimators': 842, 'clf__learning_rate': 0.024132320155915276, 'clf__num_leaves': 55, 'clf__max_depth': 10, 'clf__min_child_samples': 124, 'clf__subsample': 0.9041517965320417, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9700505870963767, 'clf__reg_lambda': 0.9560541609924877, 'clf__reg_alpha': 0.5666380894826497, 'clf__max_bin': 427}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:15:49,612] Trial 23 finished with value: 0.6559724203803652 and parameters: {'clf__n_estimators': 803, 'clf__learning_rate': 0.023799261625992725, 'clf__num_leaves': 59, 'clf__max_depth': 11, 'clf__min_child_samples': 117, 'clf__subsample': 0.9172560909836939, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9880776455651886, 'clf__reg_lambda': 0.9226487642186634, 'clf__reg_alpha': 0.5116467991533031, 'clf__max_bin': 414}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:16:48,158] Trial 24 finished with value: 0.6452989044291684 and parameters: {'clf__n_estimators': 1230, 'clf__learning_rate': 0.03644380266109123, 'clf__num_leaves': 61, 'clf__max_depth': 11, 'clf__min_child_samples': 102, 'clf__subsample': 0.9275305553232329, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.8898946609835292, 'clf__reg_lambda': 1.0857657120310276, 'clf__reg_alpha': 0.3951239439133246, 'clf__max_bin': 434}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:18:59,882] Trial 25 finished with value: 0.6427524393647556 and parameters: {'clf__n_estimators': 2104, 'clf__learning_rate': 0.0231245625612116, 'clf__num_leaves': 90, 'clf__max_depth': 11, 'clf__min_child_samples': 113, 'clf__subsample': 0.8302779628131517, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9594830567936096, 'clf__reg_lambda': 0.920804590112256, 'clf__reg_alpha': 0.47851072541261674, 'clf__max_bin': 474}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:20:07,270] Trial 26 finished with value: 0.6421945585192135 and parameters: {'clf__n_estimators': 1605, 'clf__learning_rate': 0.0465570129096388, 'clf__num_leaves': 59, 'clf__max_depth': 8, 'clf__min_child_samples': 126, 'clf__subsample': 0.9942872793263239, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9991846078397513, 'clf__reg_lambda': 1.377003360732258, 'clf__reg_alpha': 0.6813757724448617, 'clf__max_bin': 426}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:21:21,038] Trial 27 finished with value: 0.6494410354691402 and parameters: {'clf__n_estimators': 1171, 'clf__learning_rate': 0.020670546196792556, 'clf__num_leaves': 160, 'clf__max_depth': 12, 'clf__min_child_samples': 145, 'clf__subsample': 0.7036958447061955, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.8883135698003846, 'clf__reg_lambda': 1.7394634556137536, 'clf__reg_alpha': 0.8009479753034875, 'clf__max_bin': 393}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:23:10,916] Trial 28 finished with value: 0.643374487882715 and parameters: {'clf__n_estimators': 2508, 'clf__learning_rate': 0.02553127559400189, 'clf__num_leaves': 118, 'clf__max_depth': 8, 'clf__min_child_samples': 90, 'clf__subsample': 0.843264727318119, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9629204874457079, 'clf__reg_lambda': 0.6132059519683211, 'clf__reg_alpha': 0.3354509023677018, 'clf__max_bin': 454}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:24:49,273] Trial 29 finished with value: 0.6416474784950532 and parameters: {'clf__n_estimators': 2761, 'clf__learning_rate': 0.03113972038522412, 'clf__num_leaves': 83, 'clf__max_depth': 7, 'clf__min_child_samples': 69, 'clf__subsample': 0.7745068365240753, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.8038891132857455, 'clf__reg_lambda': 1.1986244398104418, 'clf__reg_alpha': 0.6883228406253208, 'clf__max_bin': 404}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:26:07,007] Trial 30 finished with value: 0.6538843707801092 and parameters: {'clf__n_estimators': 1708, 'clf__learning_rate': 0.017266836839691206, 'clf__num_leaves': 52, 'clf__max_depth': 11, 'clf__min_child_samples': 171, 'clf__subsample': 0.9533879722812734, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9512696061170631, 'clf__reg_lambda': 0.9003814425772041, 'clf__reg_alpha': 0.5034449104175329, 'clf__max_bin': 420}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:26:52,764] Trial 31 finished with value: 0.6544516762020547 and parameters: {'clf__n_estimators': 816, 'clf__learning_rate': 0.02593878156025483, 'clf__num_leaves': 67, 'clf__max_depth': 10, 'clf__min_child_samples': 121, 'clf__subsample': 0.9165276790317521, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9865987060371163, 'clf__reg_lambda': 0.8512565185557845, 'clf__reg_alpha': 0.55667636470791, 'clf__max_bin': 445}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:27:35,403] Trial 32 finished with value: 0.6495020474982625 and parameters: {'clf__n_estimators': 1073, 'clf__learning_rate': 0.040114710250633755, 'clf__num_leaves': 45, 'clf__max_depth': 9, 'clf__min_child_samples': 144, 'clf__subsample': 0.9081471133963598, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9872848052923237, 'clf__reg_lambda': 0.6526266979099256, 'clf__reg_alpha': 0.43242017041312536, 'clf__max_bin': 410}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:29:02,927] Trial 33 finished with value: 0.6484989813126196 and parameters: {'clf__n_estimators': 1350, 'clf__learning_rate': 0.02050457608498814, 'clf__num_leaves': 93, 'clf__max_depth': 11, 'clf__min_child_samples': 106, 'clf__subsample': 0.8950141394931059, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9659686093861399, 'clf__reg_lambda': 1.1786386071695465, 'clf__reg_alpha': 0.555706408984749, 'clf__max_bin': 469}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:29:33,121] Trial 34 finished with value: 0.6567758548055698 and parameters: {'clf__n_estimators': 851, 'clf__learning_rate': 0.025338704596944265, 'clf__num_leaves': 31, 'clf__max_depth': 10, 'clf__min_child_samples': 130, 'clf__subsample': 0.9681785597236978, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9327950346119563, 'clf__reg_lambda': 0.5306097329848798, 'clf__reg_alpha': 0.6249765610449841, 'clf__max_bin': 389}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:29:57,376] Trial 35 finished with value: 0.6433940644991359 and parameters: {'clf__n_estimators': 1967, 'clf__learning_rate': 0.02319773330040021, 'clf__num_leaves': 73, 'clf__max_depth': 3, 'clf__min_child_samples': 123, 'clf__subsample': 0.9625963572406169, 'clf__subsample_freq': 1, 'clf__colsample_bytree': 0.8956993217408, 'clf__reg_lambda': 0.5158415494739301, 'clf__reg_alpha': 0.6620224487217575, 'clf__max_bin': 384}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:30:38,871] Trial 36 finished with value: 0.6486106943905301 and parameters: {'clf__n_estimators': 1017, 'clf__learning_rate': 0.05104435433106007, 'clf__num_leaves': 49, 'clf__max_depth': 6, 'clf__min_child_samples': 26, 'clf__subsample': 0.7992083353426866, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9278725824978822, 'clf__reg_lambda': 0.2527586494362528, 'clf__reg_alpha': 0.7565719697893105, 'clf__max_bin': 442}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:32:56,070] Trial 37 finished with value: 0.6430398409038114 and parameters: {'clf__n_estimators': 1455, 'clf__learning_rate': 0.017213913635656355, 'clf__num_leaves': 203, 'clf__max_depth': -1, 'clf__min_child_samples': 148, 'clf__subsample': 0.974357649738508, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.6506422952327001, 'clf__reg_lambda': 0.9972066007499175, 'clf__reg_alpha': 0.8746195080975568, 'clf__max_bin': 397}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:34:42,777] Trial 38 finished with value: 0.637775422788559 and parameters: {'clf__n_estimators': 1837, 'clf__learning_rate': 0.03190625950132718, 'clf__num_leaves': 119, 'clf__max_depth': 9, 'clf__min_child_samples': 175, 'clf__subsample': 0.639151562133421, 'clf__subsample_freq': 1, 'clf__colsample_bytree': 0.9355862024990351, 'clf__reg_lambda': 0.6932373058046969, 'clf__reg_alpha': 0.6380960951402439, 'clf__max_bin': 510}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:36:16,983] Trial 39 finished with value: 0.6333351328183829 and parameters: {'clf__n_estimators': 2167, 'clf__learning_rate': 0.06874348563073383, 'clf__num_leaves': 86, 'clf__max_depth': 12, 'clf__min_child_samples': 115, 'clf__subsample': 0.704860683907979, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.6041117501326632, 'clf__reg_lambda': 0.5277538683713093, 'clf__reg_alpha': 0.03579182004480541, 'clf__max_bin': 420}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:37:07,269] Trial 40 finished with value: 0.6530926911169234 and parameters: {'clf__n_estimators': 1218, 'clf__learning_rate': 0.02139448437591364, 'clf__num_leaves': 45, 'clf__max_depth': 8, 'clf__min_child_samples': 58, 'clf__subsample': 0.941823965198618, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9127202117609001, 'clf__reg_lambda': 1.1165704645269217, 'clf__reg_alpha': 0.3005022659331348, 'clf__max_bin': 469}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:37:50,868] Trial 41 finished with value: 0.6564241731478617 and parameters: {'clf__n_estimators': 914, 'clf__learning_rate': 0.02763615842395423, 'clf__num_leaves': 33, 'clf__max_depth': 10, 'clf__min_child_samples': 137, 'clf__subsample': 0.8875580063140256, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9653353837905125, 'clf__reg_lambda': 0.7848595805703936, 'clf__reg_alpha': 0.5778496118816073, 'clf__max_bin': 413}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:38:33,776] Trial 42 finished with value: 0.6547700384683727 and parameters: {'clf__n_estimators': 1007, 'clf__learning_rate': 0.02984254301506472, 'clf__num_leaves': 43, 'clf__max_depth': 11, 'clf__min_child_samples': 136, 'clf__subsample': 0.8726961136466314, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9452306267812938, 'clf__reg_lambda': 0.9551699902198025, 'clf__reg_alpha': 0.5856239027739519, 'clf__max_bin': 388}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:39:40,477] Trial 43 finished with value: 0.6504706157180888 and parameters: {'clf__n_estimators': 1368, 'clf__learning_rate': 0.02491704883948315, 'clf__num_leaves': 65, 'clf__max_depth': 10, 'clf__min_child_samples': 152, 'clf__subsample': 0.9306925247976727, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9691975819814641, 'clf__reg_lambda': 0.8394835888255071, 'clf__reg_alpha': 0.736029579777269, 'clf__max_bin': 404}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:40:27,424] Trial 44 finished with value: 0.6499739012616708 and parameters: {'clf__n_estimators': 1163, 'clf__learning_rate': 0.035467037994115026, 'clf__num_leaves': 56, 'clf__max_depth': 12, 'clf__min_child_samples': 166, 'clf__subsample': 0.8494643517302112, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.7742700468314566, 'clf__reg_lambda': 0.6788308178135486, 'clf__reg_alpha': 0.4548933917326311, 'clf__max_bin': 372}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:40:46,686] Trial 45 finished with value: 0.594372150862438 and parameters: {'clf__n_estimators': 4253, 'clf__learning_rate': 0.027831405849066942, 'clf__num_leaves': 71, 'clf__max_depth': 1, 'clf__min_child_samples': 125, 'clf__subsample': 0.8885120879677453, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.7407017797459985, 'clf__reg_lambda': 1.3609519848930298, 'clf__reg_alpha': 0.5118141626563021, 'clf__max_bin': 347}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:41:31,598] Trial 46 finished with value: 0.6556775991128612 and parameters: {'clf__n_estimators': 803, 'clf__learning_rate': 0.01941691375461827, 'clf__num_leaves': 176, 'clf__max_depth': 9, 'clf__min_child_samples': 140, 'clf__subsample': 0.9783664713630037, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9189875591568868, 'clf__reg_lambda': 1.265357082871906, 'clf__reg_alpha': 0.7723109745017065, 'clf__max_bin': 437}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:42:31,537] Trial 47 finished with value: 0.6561113339915422 and parameters: {'clf__n_estimators': 1554, 'clf__learning_rate': 0.01805996250060597, 'clf__num_leaves': 97, 'clf__max_depth': 7, 'clf__min_child_samples': 109, 'clf__subsample': 0.9502663166756535, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.6751145298136795, 'clf__reg_lambda': 1.0421020589565395, 'clf__reg_alpha': 0.6693232461790888, 'clf__max_bin': 355}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:43:05,891] Trial 48 finished with value: 0.6526304553553922 and parameters: {'clf__n_estimators': 1544, 'clf__learning_rate': 0.012090356259890495, 'clf__num_leaves': 99, 'clf__max_depth': 6, 'clf__min_child_samples': 182, 'clf__subsample': 0.9525128588633326, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.6777935035791625, 'clf__reg_lambda': 1.5541155994607982, 'clf__reg_alpha': 0.666071360352166, 'clf__max_bin': 358}. Best is trial 22 with value: 0.656884902977991.
# [I 2025-10-14 02:43:39,828] Trial 49 finished with value: 0.6465930396639312 and parameters: {'clf__n_estimators': 1790, 'clf__learning_rate': 0.016612112722508413, 'clf__num_leaves': 40, 'clf__max_depth': 4, 'clf__min_child_samples': 107, 'clf__subsample': 0.8059215136674683, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.7203974239540504, 'clf__reg_lambda': 0.23682724338996192, 'clf__reg_alpha': 0.7074827983034586, 'clf__max_bin': 315}. Best is trial 22 with value: 0.656884902977991.
# === Optuna 결과 ===
# Best score (CV-PR-AUC): 0.6569
# Best params: {'clf__n_estimators': 842, 'clf__learning_rate': 0.024132320155915276, 'clf__num_leaves': 55, 'clf__max_depth': 10, 'clf__min_child_samples': 124, 'clf__subsample': 0.9041517965320417, 'clf__subsample_freq': 0, 'clf__colsample_bytree': 0.9700505870963767, 'clf__reg_lambda': 0.9560541609924877, 'clf__reg_alpha': 0.5666380894826497, 'clf__max_bin': 427}
# [LightGBM] [Info] Number of positive: 21106, number of negative: 21106
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.017423 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 55931
# [LightGBM] [Info] Number of data points in the train set: 42212, number of used features: 132
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# best_iteration_ (with early stopping on VAL): 698

# %%
# ---------- 6) (선택) 조기 종료를 활용한 Refit: train→val ----------
# GridSearchCV는 폴드 내부에서 학습하므로 early_stopping을 쓰기 까다롭습니다.
# 최적 파이프라인으로 "train(0.7)"에 다시 적합하면서, val(0.1)을 eval_set으로 전달하여 조기 종료를 적용합니다.
# - 파이프라인의 마지막 스텝 이름이 'clf'이므로, fit params는 'clf__' prefix로 전달합니다.
best_pipe.set_params(clf__n_estimators=5000)  # 충분히 크게 두고 조기 종료에 맡기기
best_pipe.fit(
    X_train, y_train,
    clf__eval_set=[(best_pipe.named_steps['prep'].transform(X_val), y_val)],
    clf__eval_metric='auc',
    clf__callbacks=[lgb.early_stopping(stopping_rounds=200, verbose=False)]
)

best_clf = best_pipe.named_steps['clf']
print("best_iteration_ (with early stopping on VAL):", getattr(best_clf, 'best_iteration_', None))
# Out:
# [LightGBM] [Info] Number of positive: 21106, number of negative: 21106
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022214 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 55931
# [LightGBM] [Info] Number of data points in the train set: 42212, number of used features: 132
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# best_iteration_ (with early stopping on VAL): 698

# %%
# ---------- 7) 임계값 튜닝: VAL에서 F1 최대점 ----------
from sklearn.metrics import precision_recall_curve

val_proba = best_pipe.predict_proba(X_val)[:, 1]
precisions, recalls, thresholds = precision_recall_curve(y_val, val_proba)
f1s = 2 * (precisions[:-1] * recalls[:-1]) / (precisions[:-1] + recalls[:-1] + 1e-12)
best_idx = int(np.nanargmax(f1s))
best_thr = float(thresholds[best_idx])
print(f"Best threshold from VAL(F1 max): {best_thr:.4f}")

def eval_all(y_true, proba, thr):
    pred = (proba >= thr).astype(int)
    return {
        'ACC': round(accuracy_score(y_true, pred), 4),
        'PREC': round(precision_score(y_true, pred, zero_division=0), 4),
        'RECALL': round(recall_score(y_true, pred, zero_division=0), 4),
        'F1': round(f1_score(y_true, pred, zero_division=0), 4),
        'ROC_AUC': round(roc_auc_score(y_true, proba), 4),
        'PR_AUC': round(average_precision_score(y_true, proba), 4),
        'CM': confusion_matrix(y_true, pred)
    }
# Out:
# Best threshold from VAL(F1 max): 0.3950

# %%
# ---------- 8) VAL / TEST 평가 ----------
val_metrics = eval_all(y_val, val_proba, best_thr)
test_proba = best_pipe.predict_proba(X_test)[:, 1]
test_metrics = eval_all(y_test, test_proba, best_thr)

print("\n=== VAL Metrics (thr from VAL) ===")
for k, v in val_metrics.items():
    print(f"{k}: {v}")

print("\n=== TEST Metrics (thr from VAL) ===")
for k, v in test_metrics.items():
    print(f"{k}: {v}")
# Out:
# === VAL Metrics (thr from VAL) ===
# ACC: 0.7939
# PREC: 0.5712
# RECALL: 0.6456
# F1: 0.6061
# ROC_AUC: 0.8313
# PR_AUC: 0.6397
# CM: [[2540  476]
#  [ 348  634]]
#
# === TEST Metrics (thr from VAL) ===
# ACC: 0.792
# PREC: 0.5669
# RECALL: 0.6497
# F1: 0.6055
# ROC_AUC: 0.8362
# PR_AUC: 0.6473
# CM: [[5056  975]
#  [ 688 1276]]

# %%
# ---------- 9) 중요도(상위 15) ----------
# ColumnTransformer + OrdinalEncoder를 썼으므로, 최종 피처 순서를 복원합니다.
# (주의) 인코딩 후의 컬럼명은 cat/num 합쳐진 순서이므로 간단히 이름을 재구성합니다.
enc_cat_names = [f"[CAT]{c}" for c in cat_cols]
feat_names = enc_cat_names + num_cols
importances = pd.Series(best_clf.feature_importances_, index=feat_names).sort_values(ascending=False)
print("\nTop 15 Feature Importances:")
print(importances.head(15))
# Out:
# Top 15 Feature Importances:
# [CAT]서비스_업종_코드_명    2932
# 서울시_운영_영업_개월_평균     1839
# 개업_점포_수             1727
# 프랜차이즈_점포_수          1372
# 개업_률                1291
# 점포_수                1001
# 유사_업종_점포_수           876
# 시간대_06_11_매출_금액      732
# 전체임대료                709
# 시간대_건수~06_매출_건수      637
# 연령대_60_이상_매출_건수      605
# 유흥_지출_총금액            564
# 연령대_60_이상_매출_금액      551
# 시간대_00_06_매출_금액      550
# 시간대_건수~24_매출_건수      524
# dtype: int32
